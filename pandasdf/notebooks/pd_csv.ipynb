# %%
import pandas as pd
from pathlib import Path

csv_path = Path.cwd().parent / 'csv_files' / 'nba.csv'

df = pd.read_csv(csv_path)
# removing rows with null or NAN values
df.dropna(how="any")
# Out:
# c:\Users\sreed\skonduru\work\pynotebooks\pandasdf\csv_files\nba.csv
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7     Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# ..             ...             ...     ...      ...  ...     ...     ...
# 449    Rodney Hood       Utah Jazz       5       SG   23   8-Jun     206
# 451  Chris Johnson       Utah Jazz      23       SF   26   6-Jun     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
# ...

# %%
df.sort_values(by=["Team"])
# Out:
#                  Name                Team  Number Position  Age  Height  \
# 317   Lamar Patterson       Atlanta Hawks      13       SG   24   5-Jun
# 309     Kent Bazemore       Atlanta Hawks      24       SF   26   5-Jun
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG   24   6-Jun
# 311      Kirk Hinrich       Atlanta Hawks      12       SG   35   4-Jun
# 312        Al Horford       Atlanta Hawks      15        C   30  10-Jun
# ..                ...                 ...     ...      ...  ...     ...
# 371      Jarell Eddie  Washington Wizards       8       SG   24   7-Jun
# 369      Bradley Beal  Washington Wizards       3       SG   22   5-Jun
# 368     Alan Anderson  Washington Wizards       6       SG   33   6-Jun
# 382         John Wall  Washington Wizards       2       PG   25   4-Jun
# 370      Jared Dudley  Washington Wizards       1       SF   30   7-Jun
#
#      Weight         College      Salary
# 317     225      Pittsburgh    525093.0
# ...

# %%
df_team = df.groupby(['Team']).ngroups  # number of groups

df_team = df.groupby(['Team']).groups.keys() # return groups name with indexes
df_team
df_team_by_name = df.groupby('Team').get_group('Phoenix Suns')
df_team_by_name
# Out:
#                 Name          Team  Number Position  Age  Height  Weight  \
# 121     Eric Bledsoe  Phoenix Suns       2       PG   26   1-Jun     190
# 122     Devin Booker  Phoenix Suns       1       SG   19   6-Jun     206
# 123   Chase Budinger  Phoenix Suns      10       SF   28   7-Jun     209
# 124   Tyson Chandler  Phoenix Suns       4        C   33   1-Jul     240
# 125   Archie Goodwin  Phoenix Suns      20       SG   21   5-Jun     200
# 126     John Jenkins  Phoenix Suns      23       SG   25   4-Jun     215
# 127   Brandon Knight  Phoenix Suns       3       PG   24   3-Jun     189
# 128         Alex Len  Phoenix Suns      21        C   22   1-Jul     260
# 129        Jon Leuer  Phoenix Suns      30       PF   27  10-Jun     228
# 130     Phil Pressey  Phoenix Suns      25       PG   25  11-May     175
# 131     Ronnie Price  Phoenix Suns      14       PG   32   2-Jun     190
# 132  Mirza Teletovic  Phoenix Suns      35       PF   30   9-Jun     242
# ...
