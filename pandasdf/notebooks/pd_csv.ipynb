# %%
import pandas as pd
from pathlib import Path

csv_path = Path.cwd().parent / 'csv_files' / 'nba.csv'

df = pd.read_csv(csv_path)
# removing rows with null or NAN values
df.dropna(how="any").head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6  Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %%
""" Sort_values based on column """
df.sort_values(by=["Team"])
df.sort_values(by=["Age"], ascending=False)  # sort_values by descending order.
# Out:
#                    Name                    Team  Number Position  Age  Height  \
# 304        Andre Miller       San Antonio Spurs      24       PG   40   3-Jun
# 400       Kevin Garnett  Minnesota Timberwolves      21       PF   40  11-Jun
# 298          Tim Duncan       San Antonio Spurs      21        C   40  11-Jun
# 261        Vince Carter       Memphis Grizzlies      15       SG   39   6-Jun
# 102      Pablo Prigioni    Los Angeles Clippers       9       PG   39   3-Jun
# ..                  ...                     ...     ...      ...  ...     ...
# 40   Kristaps Porzingis         New York Knicks       6       PF   20   3-Jul
# 401          Tyus Jones  Minnesota Timberwolves       1       PG   20   2-Jun
# 60       Christian Wood      Philadelphia 76ers      35       PF   20  11-Jun
# 226       Rashad Vaughn         Milwaukee Bucks      20       SG   19   6-Jun
# 122        Devin Booker            Phoenix Suns       1       SG   19   6-Jun
#
# ...

# %%
""" Pandas Group by """
df_team = df.groupby(['Team']).ngroups  # number of groups

df_team = df.groupby(['Team']).groups.keys() # return groups name with indexes
df_team
df_team_by_name = df.groupby('Team').get_group('Phoenix Suns').sort_values(by=["Age"])
df_team_by_name.head(5)
# Out:
#                Name          Team  Number Position  Age Height  Weight  \
# 122    Devin Booker  Phoenix Suns       1       SG   19  6-Jun     206
# 125  Archie Goodwin  Phoenix Suns      20       SG   21  5-Jun     200
# 128        Alex Len  Phoenix Suns      21        C   22  1-Jul     260
# 134     T.J. Warren  Phoenix Suns      12       SF   22  8-Jun     230
# 135   Alan Williams  Phoenix Suns      15        C   23  8-Jun     260
#
#                   College     Salary
# 122              Kentucky  2127840.0
# 125              Kentucky  1160160.0
# 128              Maryland  3807120.0
# 134  North Carolina State  2041080.0
# 135      UC Santa Barbara    83397.0
